# %%
import numpy as np 
A = np.array([0.,1.])
A1, A2 = A

# %%
np.clip(A,0,0.5)
# Out:
# array([0. , 0.5])

# %%
import matplotlib.pyplot as plt
import numpy as np
DGparas = np.array([[5e-1 ,5e-3, 200], [1, 3e-3, 300],[1.5, 2e-3, 400]])
for i in range(3):
    num = 10*int(DGparas[i,2])
    x = np.linspace(0, int(DGparas[i,2]), num=num, endpoint=False)
    y = np.zeros(num)
    for j in range(num):
        y[j] = DGparas[i,1]*x[j]**2 + DGparas[i,0]*x[j]
    plt.plot(x,y, label = i)
plt.xlim(0,400)
plt.ylim(0,1000)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
DGparas = np.array([[5e-1 ,5e-3, 200], [1, 3e-3, 300],[1.5, 2e-3, 400]])
for i in range(3):
    num = 10*int(DGparas[i,2])
    x = np.linspace(0, int(DGparas[i,2]), num=num, endpoint=False)
    y = np.zeros(num)
    for j in range(num):
        y[j] = 2*DGparas[i,1]*x[j] + DGparas[i,0]
    plt.plot(x,y, label = i)
plt.xlim(0,400)
plt.ylim(0,4)
plt.legend()
plt.grid()
plt.show()

# %%
import torch
import torch.distributions as dist
mu = torch.zeros(3)
sigma = torch.ones(3)
normal = dist.Independent(dist.Normal(mu,sigma+1e-6), 1)
policies_probs = dist.transforms.SigmoidTransform()
policies_probs = dist.transformed_distribution.TransformedDistribution(normal,dist.transforms.SigmoidTransform())
actions = policies_probs.sample()

# %%
policies_probs.sample()
# Out:
# tensor([0.2515, 0.1792, 0.3322])

# %%
soc = 1.5
P_BES= 1
if soc>=1 & P_BES>0:
    print(soc)
# Out:
# 1.5

# %%
import torch 
done = torch.tensor([False, True])
~done
# Out:
# tensor([ True, False])

# %%
value = torch.tensor([1.0,2.0])
value*done
# Out:
# tensor([0., 2.])

# %%
import torch
import torch.nn as nn 
import numpy as np
init_ = lambda m: init(m, nn.init.orthogonal_, lambda x: nn.init.constant_(x, 0), np.sqrt(2))
critic_linear = init_(nn.Linear(64, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c67c5ee50185> in <module>
#       3 import numpy as np
#       4 init_ = lambda m: init(m, nn.init.orthogonal_, lambda x: nn.init.constant_(x, 0), np.sqrt(2))
# ----> 5 critic_linear = init_(nn.Linear(64, 1))
#
# <ipython-input-2-c67c5ee50185> in <lambda>(m)
#       2 import torch.nn as nn
#       3 import numpy as np
# ----> 4 init_ = lambda m: init(m, nn.init.orthogonal_, lambda x: nn.init.constant_(x, 0), np.sqrt(2))
#       5 critic_linear = init_(nn.Linear(64, 1))
#
# NameError: name 'init' is not defined

# %%
import torch
_bias = nn.Parameter(torch.zeros(4).unsqueeze(1))

# %%
_bias.t().view(1, -1)
# Out:
# tensor([[0., 0., 0., 0.]], grad_fn=<ViewBackward>)

# %%
_bias.t().view(1, -1, 1, 1)
# Out:
# tensor([[[[0.]],
#
#          [[0.]],
#
#          [[0.]],
#
#          [[0.]]]], grad_fn=<ViewBackward>)

# %%
A = torch.distributions.normal.Normal(torch.zeros(4),torch.ones(4))
# Out:
# Normal(loc: torch.Size([4]), scale: torch.Size([4]))

# %%
run main.py
# Out:
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/zhaoming/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# [============================================================>                    ] 75% total_steps: 300029957
# SubprocVecEnv worker 58: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 56: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 60: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 53: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 49: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 51: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 47: KeyboardInterrupt received, and local connection is closed
# SubprocVecEnv worker 62: KeyboardInterrupt received, and local connection is closed
#
#
#
#
#
#
#
#
# Received KeyboardInterrupt
#
# Training stopped, saving model...

# %%
import torch
((torch.ones([136,3])*torch.ones([136,1])).mean())
# Out:
# tensor(1.)

# %%
A = torch.ones([8,20])
A.sum(1, True)
# Out:
# tensor([[20.],
#         [20.],
#         [20.],
#         [20.],
#         [20.],
#         [20.],
#         [20.],
#         [20.]])

# %%
EV_mu = torch.ones([1,3])
AC_prob = torch.tensor([[0.1,0.6,0.4]])
actions = torch.cat((EV_mu,AC_prob>0.5),dim=1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-ac465dc9ce42> in <module>
#       1 EV_mu = torch.ones([1,3])
#       2 AC_prob = torch.tensor([[0.1,0.6,0.4]])
# ----> 3 actions = torch.cat((EV_mu,AC_prob>0.5),dim=1)
#
# RuntimeError: Expected object of scalar type float but got scalar type bool for sequence element 1.

# %%
AC_prob.dtype
# Out:
# torch.float32

# %%
(AC_prob>0.5).to(torch.float)
# Out:
# tensor([[0., 1., 0.]])
